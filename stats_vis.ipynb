# %%
stats = {'updated': 1643526414965, 'country': 'Spain', 'countryInfo': {'_id': 724, 'iso2': 'ES', 'iso3': 'ESP', 'lat': 40, 'long': -4, 'flag': 'https://disease.sh/assets/img/flags/es.png'}, 'cases': 9779130, 'todayCases': 0, 'deaths': 92966, 'todayDeaths': 0, 'recovered': 5839859, 'todayRecovered': 0, 'active': 3846305, 'critical': 2060, 'casesPerOneMillion': 209030, 'deathsPerOneMillion': 1987, 'tests': 66213858, 'testsPerOneMillion': 1415330, 'population': 46783326, 'continent': 'Europe', 'oneCasePerPeople': 5, 'oneDeathPerPeople': 503, 'oneTestPerPeople': 1, 'activePerOneMillion': 82215.3, 'recoveredPerOneMillion': 124827.79, 'criticalPerOneMillion': 44.03}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.char.array(['recovered', 'deaths', 'active', 'critical'])
y = np.array([stats[label] for label in x])
colors = ['yellowgreen','red','gold','lightskyblue','white','lightcoral','blue','pink', 'darkgreen','yellow','grey','violet','magenta','cyan']
porcent = 100.*y/y.sum()

patches, texts = plt.pie(y, colors=colors, startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center left', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)

plt.savefig('charts/piechart.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def get_pie_path(stats, labels):
    x = np.char.array(labels)
    y = np.array([stats[label] for label in x])
    colors = ['yellowgreen','red','gold','lightskyblue','white','lightcoral','blue','pink', 'darkgreen','yellow','grey','violet','magenta','cyan']
    porcent = 100.*y/y.sum()

    patches, texts = plt.pie(y, colors=colors, startangle=90, radius=1.2)
    labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, porcent)]

    sort_legend = True
    if sort_legend:
        patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                            key=lambda x: x[2],
                                            reverse=True))

    plt.legend(patches, labels, loc='center left', bbox_to_anchor=(-0.1, 1.),
            fontsize=8)

    file_name = f'charts/{time.time()}_pirchart.png'
    plt.savefig(file_name, bbox_inches='tight')
    return file_name

def get_chart_path(stats):
    all_time_pie = get_pie_path(stats, ['recovered', 'deaths', 'active', 'critical'])
    daily_pie = get_pie_path(stats, ['todayCases', 'todayDeaths', 'todayRecovered'])
    return all_time_pie, daily_pie

# %%
get_chart_path(stats)
# Out:
# /tmp/ipykernel_30909/3132407637.py:9: RuntimeWarning: invalid value encountered in true_divide
#   porcent = 100.*y/y.sum()
# /home/pradeep707/Documents/code/chatbot/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:3052: RuntimeWarning: invalid value encountered in true_divide
#   x = x / sx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <module>
# ----> 1 get_chart_path(stats)
#
# Input In [12], in get_chart_path(stats)
#      27 def get_chart_path(stats):
#      28     all_time_pie = get_pie_path(stats, ['recovered', 'deaths', 'active', 'critical'])
# ---> 29     daily_pie = get_pie_path(stats, ['todayCases', 'todayDeaths', 'todayRecovered'])
#      30     return all_time_pie, daily_pie
#
# Input In [12], in get_pie_path(stats, labels)
# ...
